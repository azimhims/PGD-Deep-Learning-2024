# %% [markdown]
# <a href="https://colab.research.google.com/github/azimhims/PGD-Deep-Learning-2024/blob/main/spacy_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy

# %%
import spacy
nlpsm = spacy.load("en_core_web_sm")

# %%
text = "I am eating apple, while using apple:)"

# %%
doc = nlpsm(text)

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("I love coffee")
print(doc.vocab.strings["coffee"])  # 3197928453018144401
print(doc.vocab.strings[3197928453018144401])
# Out:
# 3197928453018144401
# coffee

# %%
doc = nlp("I love coffee")
for word in doc:
    lexeme = doc.vocab[word.text]
    print(lexeme.text, lexeme.orth, lexeme.shape_, lexeme.prefix_, lexeme.suffix_,
            lexeme.is_alpha, lexeme.is_digit, lexeme.is_title, lexeme.lang_)
# Out:
# I 4690420944186131903 X I I True False True en
# love 3702023516439754181 xxxx l ove True False False en
# coffee 3197928453018144401 xxxx c fee True False False en

# %%
for token in doc:
    print(token.text, token.pos_, token.dep_,token.similarity)
# Out:
# I PRON nsubj <built-in method similarity of spacy.tokens.token.Token object at 0x78f6cb5328e0>
# am AUX aux <built-in method similarity of spacy.tokens.token.Token object at 0x78f6cb533100>
# eating VERB ROOT <built-in method similarity of spacy.tokens.token.Token object at 0x78f6cb5328e0>
# Apple PROPN dobj <built-in method similarity of spacy.tokens.token.Token object at 0x78f6cb533100>
# , PUNCT punct <built-in method similarity of spacy.tokens.token.Token object at 0x78f6cb5328e0>
# while SCONJ mark <built-in method similarity of spacy.tokens.token.Token object at 0x78f6cb533100>
# using VERB advcl <built-in method similarity of spacy.tokens.token.Token object at 0x78f6cb5328e0>
# Apple PROPN compound <built-in method similarity of spacy.tokens.token.Token object at 0x78f6cb533100>
# Iphone PROPN dobj <built-in method similarity of spacy.tokens.token.Token object at 0x78f6cc73d850>
# :) PUNCT punct <built-in method similarity of spacy.tokens.token.Token object at 0x78f6d2f3d850>

# %%
for token in doc:
    print(token.text,token.pos_)
# Out:
# I PRON
# am AUX
# eating VERB
# apple NOUN
# , PUNCT
# while SCONJ
# using VERB
# Apple PROPN
# :) PUNCT

# %%
for token in doc.ents:
    print(token.text, token.label_,token.label)

# %%
# !python -m spacy download en_core_web_lg

#nnl = spacy.load("en_core_web_md")
#nlp = spacy.load("en_core_web_md")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 887.6 kB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
nlp_md = spacy.load("en_core_web_lg")

# %%
text1 = "I am eating apple"
text2 = "I am using apple"

# %%
doc = nlp_md(text1)
doc2 = nlp_md(text2)

# %%
result = doc.similarity(doc2)

# %%
result
# Out:
# 0.9695059409432913

# %%
nlp = spacy.load("en_core_web_lg")  # make sure to use larger package!
doc1 = nlp("The movie was good.")
doc2 = nlp("Fast food tastes very good.")

# Similarity of two documents
print(doc1, "<->", doc2, doc1.similarity(doc2))
# Similarity of tokens and spans
french_fries = doc1[1]
burgers = doc2[1:3]
print(french_fries, "<->", burgers, french_fries.similarity(burgers))
# Out:
# The movie was good. <-> Fast food tastes very good. 0.5041693387656124
# movie <-> food tastes 0.12285264581441879
